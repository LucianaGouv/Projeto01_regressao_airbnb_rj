# %% [markdown]
# # LazyPredict Comparison
#
# Este notebook carrega os artefatos gerados por `00_data_prep.ipynb` (rio_iqr.parquet, scalers.pt, feature_cols.json, train_idx.npy, val_idx.npy), executa LazyPredict (LazyRegressor) e grava as previsões e leaderboard em arquivos para comparação com o modelo PyTorch.

# %%
# !pip install lazyPredict
# Out:
# Requirement already satisfied: lazyPredict in ./.venv/lib/python3.12/site-packages (0.2.16)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from lazyPredict) (8.3.0)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from lazyPredict) (1.7.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from lazyPredict) (2.3.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from lazyPredict) (4.67.1)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from lazyPredict) (1.5.2)
# Requirement already satisfied: lightgbm in ./.venv/lib/python3.12/site-packages (from lazyPredict) (4.6.0)
# Requirement already satisfied: xgboost in ./.venv/lib/python3.12/site-packages (from lazyPredict) (3.0.5)
# Requirement already satisfied: pytest-runner in ./.venv/lib/python3.12/site-packages (from lazyPredict) (6.0.1)
# Requirement already satisfied: mlflow>=2.0.0 in ./.venv/lib/python3.12/site-packages (from lazyPredict) (3.4.0)
# Requirement already satisfied: mlflow-skinny==3.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (3.4.0)
# Requirement already satisfied: Flask<4 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (2.12.3)
# Requirement already satisfied: graphene<4 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (23.0.0)
# Requirement already satisfied: matplotlib<4 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (3.10.6)
# Requirement already satisfied: numpy<3 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (2.3.3)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (21.0.0)
# Requirement already satisfied: scipy<2 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (1.16.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow>=2.0.0->lazyPredict) (2.0.43)
# Requirement already satisfied: cachetools<7,>=5.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.65.0)
# Requirement already satisfied: fastapi<1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.117.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (1.37.0)
# Requirement already satisfied: packaging<26 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (6.32.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (2.11.9)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (1.1.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (4.15.0)
# Requirement already satisfied: uvicorn<1 in ./.venv/lib/python3.12/site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.36.0)
# Requirement already satisfied: Mako in ./.venv/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazyPredict) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in ./.venv/lib/python3.12/site-packages (from cryptography<46,>=43.0.0->mlflow>=2.0.0->lazyPredict) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (2.40.3)
# Requirement already satisfied: urllib3>=1.26.0 in ./.venv/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazyPredict) (2.5.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.48.0)
# Requirement already satisfied: authlib>=1.5.2 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.6.4)
# Requirement already satisfied: cyclopts>=3.0.0 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.28.1)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.14.1)
# Requirement already satisfied: openapi-core>=0.19.5 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.10.0)
# Requirement already satisfied: rich>=13.9.4 in ./.venv/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (14.1.0)
# Requirement already satisfied: blinker>=1.9.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->lazyPredict) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->lazyPredict) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->lazyPredict) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->lazyPredict) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in ./.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->lazyPredict) (3.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./.venv/lib/python3.12/site-packages (from graphene<4->mlflow>=2.0.0->lazyPredict) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./.venv/lib/python3.12/site-packages (from graphene<4->mlflow>=2.0.0->lazyPredict) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in ./.venv/lib/python3.12/site-packages (from graphene<4->mlflow>=2.0.0->lazyPredict) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.0.0->lazyPredict) (3.2.5)
# Requirement already satisfied: anyio>=4.5 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in ./.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.58b0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->lazyPredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->lazyPredict) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.4.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazyPredict) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->lazyPredict) (3.6.0)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazyPredict) (3.2.4)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.3.1)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazyPredict) (0.16.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow>=2.0.0->lazyPredict) (2.23)
# Requirement already satisfied: attrs>=23.1.0 in ./.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (25.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in ./.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in ./.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.3.1)
# Requirement already satisfied: docutils in ./.venv/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.22.2)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.27.1)
# Requirement already satisfied: isodate in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.3.4)
# Requirement already satisfied: more-itertools in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.7.2)
# Requirement already satisfied: parse in ./.venv/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in ./.venv/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.4.4)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in ./.venv/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (1.12.0)
# Requirement already satisfied: email-validator>=2.0.0 in ./.venv/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in ./.venv/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazyPredict) (0.1.2)
# Requirement already satisfied: nvidia-nccl-cu12 in ./.venv/lib/python3.12/site-packages (from xgboost->lazyPredict) (2.27.3)

# %% [markdown]
# Iniciando variaveis a partir dos arquivos gerados pelo airbnb_predictor.

# %%
# ---------------------------------------------------------------------
# 1) Extract features (X) and target (y) from the DataFrame
# ---------------------------------------------------------------------
from pathlib import Path
import json, os
import numpy as np
import pandas as pd
import torch
ROOT = Path('.')
OUT = ROOT / 'outputs'
# Validate expected files
expected = ['rio_iqr.parquet','feature_cols.json','scalers.pt','train_idx.npy','val_idx.npy']
missing = [f for f in expected if not (OUT / f).exists()]
if missing:
    raise FileNotFoundError(f'Missing required artifacts in outputs/: {missing}. Run 00_data_prep.ipynb or lesson04_luciana.ipynb save cells first.')

# Load preprocessed table and meta
rio = pd.read_parquet(OUT / 'rio_iqr.parquet')
with open(OUT / 'feature_cols.json','r',encoding='utf-8') as f:
    feature_cols = json.load(f)
# Robust scalers loader to handle PyTorch 2.6+ weights_only default change and allowlisting
def safe_torch_load(path):
    path = str(path)
    try:
        # Preferred: normal load (works for most files)
        return torch.load(path, map_location='cpu')
    except Exception as e1:
        # Try loading with weights_only=False (may execute arbitrary code) if file is trusted
        try:
            return torch.load(path, map_location='cpu', weights_only=False)
        except Exception as e2:
            # Final attempt: allowlist the numpy multiarray reconstruct if present (trusted file only)
            try:
                torch.serialization.add_safe_globals(["numpy.core.multiarray._reconstruct"])
                return torch.load(path, map_location='cpu')
            except Exception as e3:
                # Re-raise the original error with context
                raise RuntimeError(f'Failed to load {path}: {e1} | {e2} | {e3}') from e3
scalers = safe_torch_load(OUT / 'scalers.pt')
train_idx = np.load(OUT / 'train_idx.npy', allow_pickle=False)
val_idx = np.load(OUT / 'val_idx.npy', allow_pickle=False)

# Build arrays (features must exist in rio)
for c in feature_cols:
    if c not in rio.columns:
        raise KeyError(f"Feature {c} declared in feature_cols.json not found in rio_iqr.parquet")

X = rio[feature_cols].to_numpy(dtype=np.float32)
y = rio['price'].to_numpy(dtype=np.float32).ravel()

# Use saved train/val indices to create the same split
X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y[train_idx], y[val_idx]

print('Loaded artifacts from outputs/. Shapes:')
print('  full X:', X.shape, 'y:', y.shape)
print('  X_train:', X_train.shape, 'X_val:', X_val.shape)
print('  y_train:', y_train.shape, 'y_val:', y_val.shape)

# Quick sanity checks
assert not np.isnan(X_train).any(), 'Found NaNs in X_train. Clean/impute before running LazyPredict.'
assert not np.isnan(X_val).any(), 'Found NaNs in X_val. Clean/impute before running LazyPredict.'
assert not np.isnan(y_train).any(), 'Found NaNs in y_train.'
assert not np.isnan(y_val).any(), 'Found NaNs in y_val.'
# Out:
# Loaded artifacts from outputs/. Shapes:
#   full X: (20923, 12) y: (20923,)
#   X_train: (16738, 12) X_val: (4185, 12)
#   y_train: (16738,) y_val: (4185,)

# %% [markdown]
# Com as variaveis lidas dos arquivos vamos usar o lazypredict

# %%
# Optional: install lazypredict if missing (uncomment to install)
# !pip install lazypredict
from lazypredict.Supervised import LazyRegressor
from pathlib import Path
ROOT = Path('.')
OUT = ROOT / 'outputs'
# Ensure we're loading the same artifacts from outputs/ (not the repo root)
rio = pd.read_parquet(OUT / 'rio_iqr.parquet')
with open(OUT / 'feature_cols.json', 'r', encoding='utf-8') as f: feature_cols = json.load(f)
# Rebuild arrays in this cell to guarantee consistency
X = rio[feature_cols].to_numpy(dtype=np.float32)
y = rio['price'].to_numpy(dtype=np.float32).ravel()
train_idx = np.load(OUT / 'train_idx.npy')
val_idx = np.load(OUT / 'val_idx.npy')
X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y[train_idx], y[val_idx]
# Run LazyPredict on the consistent split
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_val, y_train, y_val)
# models is a DataFrame summary; predictions may be a per-sample DataFrame or a per-model summary depending on version
models.to_csv(OUT / 'lazypredict_models_df.csv')
predictions.to_pickle(OUT / 'lazypredict_predictions.pkl')
# Compute leaderboard robustly
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
rows = []
# Case A: predictions is a per-sample DataFrame with shape (n_samples, n_models)
if isinstance(predictions, pd.DataFrame) and predictions.shape[0] == len(y_val):
    for name in predictions.columns:
        y_pred = predictions[name].to_numpy().ravel()
        rows.append({'Model': name, 'RMSE': float(np.sqrt(mean_squared_error(y_val, y_pred))), 'MAE': float(mean_absolute_error(y_val, y_pred)), 'R2': float(r2_score(y_val, y_pred))})
# Case B: predictions is a small summary (e.g., 42 rows x metrics). Fall back to models DataFrame columns
else:
    # Try to extract RMSE/MAE/R2 from models summary if available
    md = models.copy()
    cols = {c.lower(): c for c in md.columns}
    rmse_col = next((cols[c] for c in cols if 'rmse' in c), None)
    mae_col  = next((cols[c] for c in cols if 'mae' in c), None)
    r2_col   = next((cols[c] for c in cols if 'r2' in c), None)
    for idx, row in md.iterrows():
        rows.append({'Model': idx, 'RMSE': float(row[rmse_col]) if rmse_col else np.nan, 'MAE': float(row[mae_col]) if mae_col else np.nan, 'R2': float(row[r2_col]) if r2_col else np.nan})
leader = pd.DataFrame(rows).sort_values('RMSE').reset_index(drop=True)
leader.to_csv(OUT / 'leaderboard_lazypredict.csv', index=False)
print('LazyPredict finished — artifacts saved: outputs/lazypredict_models_df.csv, outputs/lazypredict_predictions.pkl, outputs/leaderboard_lazypredict.csv')
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000538 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 211
# [LightGBM] [Info] Number of data points in the train set: 16738, number of used features: 10
# [LightGBM] [Info] Start training from score 377.048990
# LazyPredict finished — artifacts saved: outputs/lazypredict_models_df.csv, outputs/lazypredict_predictions.pkl, outputs/leaderboard_lazypredict.csv
